# %% [markdown]
# # SUBBAB 6: SCALAR
#
# **NO SUBBAB : 6**
#
# Topik ini membahas tentang skalar — nilai tunggal tanpa dimensi (rank 0 tensor).

# %% [markdown]
# ## Soal No. 1 — Python Native
#
# Buat variabel skalar `x` dan simpan suatu nilai skalar.

# %%
# Buat variabel skalar x dan simpan suatu nilai skalar
x = 10
x

# %%
# Tampilkan tipe data dari x
type(x)

# %%
# Buat variabel skalar y dan simpan suatu nilai skalar
y = 5
y

# %%
# Jumlahkan x + y
py_sum = x + y
py_sum

# %%
# Tampilkan tipe data dari py_sum
type(py_sum)

# %%
# Buat variabel bernama x_float dan simpan suatu nilai desimal
# Jumlahkan x_float dengan y
x_float = 3.14
float_sum = x_float + y
float_sum

# %%
# Tampilkan tipe data dari float_sum
type(float_sum)

# %% [markdown]
# ## Soal No. 2 — TensorFlow
#
# Ulangi soal No. 1 menggunakan TensorFlow.

# %%
import tensorflow as tf

# %%
# Buat variabel skalar x menggunakan TensorFlow
x_tf = tf.Variable(10, dtype=tf.int16)
x_tf

# %%
# Tampilkan shape dari x_tf (skalar = shape kosong)
x_tf.shape

# %%
# Buat variabel skalar y
y_tf = tf.Variable(5, dtype=tf.int16)
y_tf

# %%
# Jumlahkan x_tf + y_tf dengan operator +
x_tf + y_tf

# %%
# Jumlahkan menggunakan tf.add
tf_sum = tf.add(x_tf, y_tf)
tf_sum

# %%
# Konversi hasil ke numpy
tf_sum.numpy()

# %%
# Tampilkan tipe data dari tf_sum
type(tf_sum.numpy())

# %%
# Buat variabel float desimal menggunakan TensorFlow
x_float_tf = tf.Variable(3.14, dtype=tf.float16)
x_float_tf

# %% [markdown]
# ## Soal No. 3 — PyTorch
#
# Ulangi soal No. 1 menggunakan PyTorch.

# %%
import torch

# %%
# Buat variabel skalar x menggunakan PyTorch
x_pt = torch.tensor(10)
x_pt

# %%
# Tampilkan shape dari x_pt (skalar = shape kosong)
x_pt.shape

# %%
# Buat variabel skalar y
y_pt = torch.tensor(5)
y_pt

# %%
# Jumlahkan x_pt + y_pt
pt_sum = x_pt + y_pt
pt_sum

# %%
# Tampilkan tipe data dari pt_sum
type(pt_sum)

# %%
# Buat variabel float desimal menggunakan PyTorch
x_float_pt = torch.tensor(3.14, dtype=torch.float16)
x_float_pt

# %%
# Tampilkan shape dari x_float_pt
x_float_pt.shape
